# %%
# % rm -rf /content/checkpoints

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Tue Mar  8 21:48:12 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# !pip install terminaltables
# !pip install --upgrade --no-cache-dir gdown

from IPython.display import clear_output 
clear_output()

# Clone from Github Repository
! git init .
! git remote add origin https://github.com/RichardMinsooGo-ML/Pytorch-Yolo-3d-Yolov3.git
# ! git pull origin master
! git pull origin main
# https://github.com/RichardMinsooGo-ML/Pytorch-Yolo-3d-Yolov3.git
# Out:
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 1059, done.
# remote: Total 1059 (delta 0), reused 0 (delta 0), pack-reused 1059
# Receiving objects: 100% (1059/1059), 686.08 MiB | 14.15 MiB/s, done.
# Resolving deltas: 100% (155/155), done.
# From https://github.com/RichardMinsooGo-ML/Pytorch-Yolo-3d-Yolov3
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# Checking out files: 100% (1112/1112), done.

# %%
# Download Darknet Weights
# ! wget https://pjreddie.com/media/files/yolo-voc.weights 
! wget https://pjreddie.com/media/files/yolov3-tiny.weights 
! wget https://pjreddie.com/media/files/yolov3.weights
# ! wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights 
# ! wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.weights

import shutil
shutil.move("/content/yolov3-tiny.weights", "/content/checkpoints")
shutil.move("/content/yolov3.weights", "/content/checkpoints")
# shutil.move("/content/yolov4-tiny.weights", "/content/checkpoints")
# shutil.move("/content/yolov4.weights", "/content/checkpoints") 
% rm -rf sample_data
# Out:
# --2022-03-08 21:49:36--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M  15.4MB/s    in 2.2s
#
# 2022-03-08 21:49:39 (15.4 MB/s) - ‘yolov3-tiny.weights’ saved [35434956/35434956]
#
# --2022-03-08 21:49:39--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  23.1MB/s    in 11s
#
# 2022-03-08 21:49:51 (21.7 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %% [markdown]
# ### Pretrained weigth download from Auther's Google Drive

# %%
# Yolo 3D - Yolo v3
# https://drive.google.com/file/d/15Hza0MjND3EWJDOt8R0XBXOZnCRoMA2o/view?usp=sharing
import gdown
google_path = 'https://drive.google.com/uc?id='
file_id = '15Hza0MjND3EWJDOt8R0XBXOZnCRoMA2o'
output_name = 'Model_yolo3d_yolov3.pth'
gdown.download(google_path+file_id,output_name,quiet=False)

# Yolo 3D - Yolo v3-tiny
# https://drive.google.com/file/d/1IUXbc2dIm-Qowhwb44aCHJze536dJcwU/view?usp=sharing
google_path = 'https://drive.google.com/uc?id='
file_id = '1IUXbc2dIm-Qowhwb44aCHJze536dJcwU'
output_name = 'Model_yolo3d_yolov3_tiny.pth'
gdown.download(google_path+file_id,output_name,quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15Hza0MjND3EWJDOt8R0XBXOZnCRoMA2o
# To: /content/Model_yolo3d_yolov3.pth
# 100%|██████████| 247M/247M [00:03<00:00, 75.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1IUXbc2dIm-Qowhwb44aCHJze536dJcwU
# To: /content/Model_yolo3d_yolov3_tiny.pth
# 100%|██████████| 34.8M/34.8M [00:00<00:00, 152MB/s]
# 'Model_yolo3d_yolov3_tiny.pth'

# %%
shutil.move("/content/Model_yolo3d_yolov3.pth", "/content/checkpoints")
shutil.move("/content/Model_yolo3d_yolov3_tiny.pth", "/content/checkpoints")
# Out:
# '/content/checkpoints/Model_yolo3d_yolov3_tiny.pth'

# %% [markdown]
# ## Dataset download from Auther's Google Drive

# %%
"""
shutil.copy("/content/gdrive/MyDrive/Obj_detection_Torch_3d/Dataset_Kitti/Complex-YOLOv4_Data_2.zip", "/content/Complex-YOLOv4_Data_2.zip")
shutil.copy("/content/gdrive/MyDrive/Obj_detection_Torch_3d/Dataset_Kitti/Complex-YOLOv4_Data_1.zip", "/content/Complex-YOLOv4_Data_1.zip")
"""

# Due to the size of data it was separated with two files
# https://drive.google.com/file/d/17NrrnO-Uw_foiGlPtXXr3IalQUhmZxGz/view?usp=sharing
import gdown
google_path = 'https://drive.google.com/uc?id='
file_id = '17NrrnO-Uw_foiGlPtXXr3IalQUhmZxGz'
output_name = 'Complex-YOLOv4_Data_1.zip'
gdown.download(google_path+file_id,output_name,quiet=False)

# Due to the size of data it was separated with two files
# https://drive.google.com/file/d/1_WIldJYOrxmVVSjm0no10Llg8vi3VstE/view?usp=sharing
google_path = 'https://drive.google.com/uc?id='
file_id = '1_WIldJYOrxmVVSjm0no10Llg8vi3VstE'
output_name = 'Complex-YOLOv4_Data_2.zip'
gdown.download(google_path+file_id,output_name,quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=17NrrnO-Uw_foiGlPtXXr3IalQUhmZxGz
# To: /content/Complex-YOLOv4_Data_1.zip
# 100%|██████████| 6.12G/6.12G [00:29<00:00, 210MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1_WIldJYOrxmVVSjm0no10Llg8vi3VstE
# To: /content/Complex-YOLOv4_Data_2.zip
# 100%|██████████| 7.81G/7.81G [00:32<00:00, 241MB/s]
# 'Complex-YOLOv4_Data_2.zip'

# %%
# !unzip /content/Complex-YOLOv4_Data_1.zip -d /content/
# !rm /content/Complex-YOLOv4_Data_1.zip
clear_output()

# !unzip /content/Complex-YOLOv4_Data_2.zip -d /content/
# !rm /content/Complex-YOLOv4_Data_2.zip
clear_output()

# %% [markdown]
# ## Train from pre-trained weight

# %%
! python train.py --model_def config/cfg/yolo3d_yolov3.cfg --num_epochs 3 --pretrained_path checkpoints/Model_yolo3d_yolov3.pth --save_path checkpoints/Model_yolo3d_yolov3.pth
# Out:
# Trained pytorch weight loaded!
# 100% 1414/1414 [04:15<00:00,  5.53it/s]
# Global_epoch : 1 / loss : 1.64519 Saved at checkpoints/Model_yolo3d_yolov3.pth
# 100% 1414/1414 [04:14<00:00,  5.55it/s]
# Global_epoch : 2 / loss : 1.42303 Saved at checkpoints/Model_yolo3d_yolov3.pth
# 100% 1414/1414 [04:14<00:00,  5.55it/s]
# Global_epoch : 3 / loss : 1.42303 Saved at checkpoints/Model_yolo3d_yolov3.pth
#
# ---- Evaluating Model ----
# 100% 1414/1414 [02:25<00:00,  9.72it/s]
# Computing AP: 100% 3/3 [00:00<00:00, 161.53it/s]
# +-------+------------+---------+
# | Index | Class name | AP      |
# +-------+------------+---------+
# | 0     | Car        | 0.95983 |
# | 1     | Pedestrian | 0.69091 |
# | 2     | Cyclist    | 0.74424 |
# +-------+------------+---------+
# ---- mAP 0.7983264879696504

# %% [markdown]
# ## Train from Darknet weight - YOLO 3D - Yolo V3
#
# 충분한 학습이 이루어 지지 않으면 mAP 계산시에 에러가 날수 있습니다.
# Darknet으로 부터 어느정도 학습하려면 Colab 환경에서 몇달이 걸립니다.
# 따라서, 해당 모델을 가지고 시험하려면 pretrained-weight를 사용하시면 됩니다.

# %%
! ! python train.py --model_def config/cfg/yolo3d_yolov3.cfg --num_epochs 3 --pretrained_path /content/checkpoints/yolov3.weights --save_path checkpoints/Model_yolo3d_yolov3.pth
# Out:
# Darknet weight loaded!
# 100% 1414/1414 [04:15<00:00,  5.53it/s]
# Global_epoch : 1 / loss : 208.21435 Saved at checkpoints/Model_yolo3d_yolov3.pth
# 100% 1414/1414 [04:16<00:00,  5.52it/s]
# Global_epoch : 2 / loss : 175.88879 Saved at checkpoints/Model_yolo3d_yolov3.pth
# 100% 1414/1414 [04:15<00:00,  5.53it/s]
# Global_epoch : 3 / loss : 175.88879 Saved at checkpoints/Model_yolo3d_yolov3.pth
#
# ---- Evaluating Model ----
# 100% 1414/1414 [01:16<00:00, 18.44it/s]
# Traceback (most recent call last):
#   File "train.py", line 204, in <module>
#     main()
#   File "train.py", line 184, in main
#     precision, recall, AP, f1, ap_class = evaluate_mAP(val_dataloader, model, configs)
#   File "/content/eval_mAP.py", line 44, in evaluate_mAP
#     true_positives, pred_scores, pred_labels = [np.concatenate(x, 0) for x in list(zip(*sample_metrics))]
# ValueError: not enough values to unpack (expected 3, got 0)

# %% [markdown]
# ## Train from pre-trained weight - YOLO 3D - Yolo V3-tiny

# %%
! python train.py  --model_def config/cfg/yolo3d_yolov3_tiny.cfg --num_epochs 3 --pretrained_path checkpoints/Model_yolo3d_yolov3_tiny.pth --save_path checkpoints/Model_yolo3d_yolov3_tiny.pth
# Out:
# Trained pytorch weight loaded!
# 100% 1414/1414 [02:12<00:00, 10.65it/s]
# Global_epoch : 1 / loss : 0.53761 Saved at checkpoints/Model_yolo3d_yolov3_tiny.pth
# 100% 1414/1414 [02:12<00:00, 10.71it/s]
# Global_epoch : 2 / loss : 0.42021 Saved at checkpoints/Model_yolo3d_yolov3_tiny.pth
# 100% 1414/1414 [02:13<00:00, 10.59it/s]
# Global_epoch : 3 / loss : 0.42021 Saved at checkpoints/Model_yolo3d_yolov3_tiny.pth
#
# ---- Evaluating Model ----
# 100% 1414/1414 [01:44<00:00, 13.49it/s]
# Computing AP: 100% 3/3 [00:00<00:00, 182.43it/s]
# +-------+------------+---------+
# | Index | Class name | AP      |
# +-------+------------+---------+
# | 0     | Car        | 0.98432 |
# | 1     | Pedestrian | 0.55127 |
# | 2     | Cyclist    | 0.47375 |
# +-------+------------+---------+
# ---- mAP 0.6697798987656284

# %% [markdown]
# ## Train from Darknet weight - YOLO 3D - Yolo V3-tiny
#
#
# 충분한 학습이 이루어 지지 않으면 mAP 계산시에 에러가 날수 있습니다.
# Darknet으로 부터 어느정도 학습하려면 Colab 환경에서 몇달이 걸립니다.
# 따라서, 해당 모델을 가지고 시험하려면 pretrained-weight를 사용하시면 됩니다.

# %%
! python train.py  --model_def config/cfg/yolo3d_yolov3_tiny.cfg --num_epochs 3 --pretrained_path /content/checkpoints/yolov3-tiny.weights --save_path checkpoints/Model_yolo3d_yolov3_tiny.pth
# Out:
# Darknet weight loaded!
# 100% 1414/1414 [02:13<00:00, 10.59it/s]
# Global_epoch : 1 / loss : 52.65622 Saved at checkpoints/Model_yolo3d_yolov3_tiny.pth
#  81% 1149/1414 [01:47<00:24, 10.70it/s]
