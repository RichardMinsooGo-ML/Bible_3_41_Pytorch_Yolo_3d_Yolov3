# %% [markdown]
# # 1. [Opt] Check GPU Type

# %%
# Check GPU Type
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
    print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
    print('and then re-execute this cell.')
else:
    print(gpu_info)
# Out:
# Fri Dec 16 21:33:01 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P0    28W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # 2. Git Clone from Github Repository to root directory
# At Colab, location is "/content/".
#
# Using `$ git clone https://github.com/lainyzine/git-clone.git` will load the Github repository with the name of the repository. With Colab, it can be convenient to work in the root directory. You can use the command to call the root directory as shown below.
#
# According to the Github repository, we can use `! git pull origin main` or `! Just use git pull origin master`.

# %%
! git init .
! git remote add origin https://github.com/RichardMinsooGo-ML/Bible_3_41_Pytorch_Yolo_3d_Yolov3.git
# ! git pull origin master
! git pull origin main
# Out:
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 1078, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 1078 (delta 8), reused 4 (delta 1), pack-reused 1059
# Receiving objects: 100% (1078/1078), 686.09 MiB | 17.33 MiB/s, done.
# Resolving deltas: 100% (163/163), done.
# From https://github.com/RichardMinsooGo-ML/Bible_3_41_Pytorch_Yolo_3d_Yolov3
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# Checking out files: 100% (1113/1113), done.

# %% [markdown]
# # 3. import clear_output

# %%
from IPython.display import clear_output 
clear_output()

# %% [markdown]
# # 4. Kitti dataset download from Auther's Github repository

# %%
# !pip install --upgrade --no-cache-dir gdown

# Due to the size of data it was separated with two files
import gdown
google_path = 'https://drive.google.com/uc?id='
file_id = '17NrrnO-Uw_foiGlPtXXr3IalQUhmZxGz'
output_name = 'Complex-YOLOv4_Data_1.zip'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/17NrrnO-Uw_foiGlPtXXr3IalQUhmZxGz/view?usp=sharing

# Due to the size of data it was separated with two files
google_path = 'https://drive.google.com/uc?id='
file_id = '1_WIldJYOrxmVVSjm0no10Llg8vi3VstE'
output_name = 'Complex-YOLOv4_Data_2.zip'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1_WIldJYOrxmVVSjm0no10Llg8vi3VstE/view?usp=sharing

# !unzip -o /content/Complex-YOLOv4_Data_1.zip -d /content/
clear_output()
# !rm /content/Complex-YOLOv4_Data_1.zip

# !unzip -o /content/Complex-YOLOv4_Data_2.zip -d /content/
clear_output()
# !rm /content/Complex-YOLOv4_Data_2.zip

# %% [markdown]
# # 5. [Opt] Check Memory Space

# %%
# Memory Space
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
    print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
    print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
    print('re-execute this cell.')
else:
    print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# # 6. install terminaltables for Ascii Table print

# %%
# !pip install terminaltables
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # 7. Download Darknet Weights

# %%
# Download Darknet Weights
# ! wget https://pjreddie.com/media/files/yolo-voc.weights 
! wget https://pjreddie.com/media/files/yolov3-tiny.weights 
! wget https://pjreddie.com/media/files/yolov3.weights
# ! wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights 
# ! wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.weights

import shutil
shutil.move("/content/yolov3-tiny.weights", "/content/checkpoints")
shutil.move("/content/yolov3.weights", "/content/checkpoints")
# shutil.move("/content/yolov4-tiny.weights", "/content/tmp")
# shutil.move("/content/yolov4.weights", "/content/tmp") 
shutil.rmtree("sample_data")
# Out:
# --2022-12-16 21:40:15--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M  8.03MB/s    in 5.0s
#
# 2022-12-16 21:40:20 (6.76 MB/s) - ‘yolov3-tiny.weights’ saved [35434956/35434956]
#
# --2022-12-16 21:40:21--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  18.3MB/s    in 15s
#
# ...

# %% [markdown]
# # 8. Yolo 3D - Yolo V3 Pre-Trained Weight gdown from Auther's GDrive

# %%
google_path = 'https://drive.google.com/uc?id='
file_id = '15Hza0MjND3EWJDOt8R0XBXOZnCRoMA2o'
output_name = 'Model_yolo3d_yolov3.pth'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/15Hza0MjND3EWJDOt8R0XBXOZnCRoMA2o/view?usp=sharing

shutil.move("/content/Model_yolo3d_yolov3.pth", "/content/checkpoints")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15Hza0MjND3EWJDOt8R0XBXOZnCRoMA2o
# To: /content/Model_yolo3d_yolov3.pth
# 100%|██████████| 247M/247M [00:07<00:00, 34.6MB/s]
# '/content/checkpoints/Model_yolo3d_yolov3.pth'

# %% [markdown]
# # 9. Yolo 3D - Yolo V3-tiny Pre-Trained Weight gdown from Auther's GDrive

# %%
google_path = 'https://drive.google.com/uc?id='
file_id = '1IUXbc2dIm-Qowhwb44aCHJze536dJcwU'
output_name = 'Model_yolo3d_yolov3_tiny.pth'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1IUXbc2dIm-Qowhwb44aCHJze536dJcwU/view?usp=sharing

shutil.move("/content/Model_yolo3d_yolov3_tiny.pth", "/content/checkpoints")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1IUXbc2dIm-Qowhwb44aCHJze536dJcwU
# To: /content/Model_yolo3d_yolov3_tiny.pth
# 100%|██████████| 34.8M/34.8M [00:00<00:00, 150MB/s]
# '/content/checkpoints/Model_yolo3d_yolov3_tiny.pth'

# %%
# from google.colab import drive 
# drive.mount('/content/gdrive/')

# %% [markdown]
# # 10. Train YOLO v3 from Pre-trained Weights

# %%
! python train.py --num_epochs 3 --batch_size 4 --model_def config/cfg/yolo3d_yolov3.cfg --pretrained_path checkpoints/Model_yolo3d_yolov3.pth --save_path checkpoints/Model_yolo3d_yolov3.pth
# Out:
# cuda
# using darknet
# [INFO] No error, the convolution haven't activate linear
# [INFO] No error, the convolution haven't activate linear
# [INFO] No error, the convolution haven't activate linear
# checkpoints/Model_yolo3d_yolov3.pth
# Traceback (most recent call last):
#   File "train.py", line 228, in <module>
#     main()
#   File "train.py", line 43, in main
#     model.load_state_dict(torch.load(configs.pretrained_path))
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 1667, in load_state_dict
#     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# RuntimeError: Error(s) in loading state_dict for DataParallel:
# ...

# %% [markdown]
# # 11. Train YOLO v3 from Darknet Weights

# %%
! python train.py --num_epochs 6 --batch_size 4 --model_def config/cfg/yolo3d_yolov3.cfg --pretrained_path /content/checkpoints/yolov3.weights --save_path checkpoints/Model_yolo3d_yolov3.pth
# Out:
# cuda
# /content/checkpoints/yolov3.weights
# Darknet weight loaded!
# 578
#   0% 0/578 [00:04<?, ?it/s]
# Traceback (most recent call last):
#   File "train.py", line 317, in <module>
#     main()
#   File "train.py", line 201, in main
#     total_loss, outputs = model(imgs, targets)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 1190, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/content/models/models.py", line 143, in forward
#     x, layer_loss = module[0](x, targets, img_dim)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 1190, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/content/models/yolo_layer.py", line 186, in forward
#     self.compute_grid_offsets(grid_size)
#   File "/content/models/yolo_layer.py", line 57, in compute_grid_offsets
#     self.scaled_anchors_polygons, self.sa_volumes, self.sa_low_hs, self.sa_high_hs = get_polygons_areas_fix_xyz(
# ...

# %% [markdown]
# # 12. Train YOLO v3-tiny from Pre-trained Weights

# %%
! python train.py --num_epochs 3 --batch_size 16  --model_def config/cfg/yolo3d_yolov3_tiny.cfg --pretrained_path checkpoints/Model_yolo3d_yolov3_tiny.pth --save_path checkpoints/Model_yolo3d_yolov3_tiny.pth
# Out:
# cuda
# checkpoints/Model_yolo3d_yolov3_tiny.pth
# Trained pytorch weight loaded!
# 144
#   0% 0/144 [00:08<?, ?it/s]
# Traceback (most recent call last):
#   File "train.py", line 317, in <module>
#     main()
#   File "train.py", line 201, in main
#     total_loss, outputs = model(imgs, targets)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 1190, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/content/models/models.py", line 143, in forward
#     x, layer_loss = module[0](x, targets, img_dim)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 1190, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/content/models/yolo_layer.py", line 186, in forward
#     self.compute_grid_offsets(grid_size)
#   File "/content/models/yolo_layer.py", line 57, in compute_grid_offsets
# ...

# %% [markdown]
# # 13. Train YOLO v3-tiny from Darknet Weights

# %%
! python train.py --num_epochs 8 --batch_size 16  --model_def config/cfg/yolo3d_yolov3_tiny.cfg --pretrained_path /content/checkpoints/yolov3-tiny.weights --save_path checkpoints/Model_yolo3d_yolov3_tiny.pth
# Out:
# cuda
# /content/checkpoints/yolov3-tiny.weights
# Darknet weight loaded!
# 144
#   0% 0/144 [00:07<?, ?it/s]
# Traceback (most recent call last):
#   File "train.py", line 317, in <module>
#     main()
#   File "train.py", line 201, in main
#     total_loss, outputs = model(imgs, targets)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 1190, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/content/models/models.py", line 143, in forward
#     x, layer_loss = module[0](x, targets, img_dim)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 1190, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/content/models/yolo_layer.py", line 186, in forward
#     self.compute_grid_offsets(grid_size)
#   File "/content/models/yolo_layer.py", line 57, in compute_grid_offsets
#     self.scaled_anchors_polygons, self.sa_volumes, self.sa_low_hs, self.sa_high_hs = get_polygons_areas_fix_xyz(
# ...
